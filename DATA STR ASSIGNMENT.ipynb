# %% [markdown]
# DATA TYPE AND STRUCTURE THEORY QUESTIONS :
#
#
# Q. What are data structures, and why are they important ?
# ANS: Data structures are ways of organizing and storing data in a computer so that it can be accessed and modified efficiently.
#      They are important for its efficiency and scalability.
#
# Q.  Explain the difference between mutable and immutable data types with examples.
# ANS: Mutable data types:
#      Definition: Mutable objects can be changed after creation.
#      Examples in Python: list, dict, set.
#      Immutable data types:
#      definition: Immutable objects cannot be changed after creation.
#      Examples in Python: int, float, bool, str, tuple.
#
# Q.  What are the main differences between lists and tuples in Python ?
# ANS: Main difference in lists and python are its mutability, syntex and performance. Lists are mutable, uses in sqaure bracket and slightly slower          than tuples. Tuples are immutable, used in parenthesis and faster than lists.
#
# Q. Describe how dictionaries store data ?
# ANS: A dictionary in Python is a collection of key-value pairs, where each key maps to a value. It is unordered before Python 3.7, but as of Python         3.7+, dictionaries preserve insertion order.
#
# Q. Why might you use a set instead of a list in Python ?
# ANS: You might use a set instead of a list in Python for a few key reasons, especially when working with unique items or when performance matters.
#      A set automatically removes duplicates. If you don’t want repeated elements, a set is ideal.
#
# Q. What is a string in Python, and how is it different from a list ?
# ANS: A string in Python is a sequence of Unicode characters, enclosed in quotes. Each character in the string has an index (starting from 0).
#      Strings are immutable — once created, they cannot be changed.A list is a collection of items (elements), which can be of any type (numbers,            strings, other lists, etc.), and is enclosed in square brackets.
#
# Q. How do tuples ensure data integrity in Python?
# ANS: Tuples in Python help ensure data integrity by being immutable — once created, their contents cannot be changed. This behavior is essential when       you want to protect data from accidental modification.
#
# Q. What is a hash table, and how does it relate to dictionaries in Python?
# ANS: A hash table is a data structure that stores key-value pairs and provides very fast access to values based on their keys.Python dictionaries are       implemented using hash tables under the hood.
#
# Q. Can lists contain different data types in Python ?
# ANS: Yes. In Python, lists can contain different data types all at once. Python lists are heterogeneous, meaning the elements inside a single list          don’t have to be of the same type. You can mix integers, strings, floats, objects, even other lists.
#
# Q. Explain why strings are immutable in Python ?
# ANS: Immutability allows Python to intern strings (reuse identical string objects) for efficiency. Since strings don’t change, Python can safely share      them in memory without copying.
#
# Q. What advantages do dictionaries offer over lists for certain tasks ?
# ANS: Dictionaries offer several advantages over lists for specific tasks, mainly due to how they organize and access data. Use dictionaries when you        want fast, meaningful access to data by keys and need to organize data as key-value pairs.
#
# Q. Describe a scenario where using a tuple would be preferable over a list ?
# ANS: Scenario: Storing Fixed, Immutable Data
#      location_data = {
#     (40.7128, -74.0060): "New York City",
#     (34.0522, -118.2437): "Los Angeles"}
#
# Q. How do sets handle duplicate values in Python ?
# ANS: In Python, sets automatically remove duplicate values — they only store unique elements. When you add an element to a set, Python checks if that       element is already present. If it is, the set ignores the duplicate and keeps only one copy. This behavior happens automatically without extra         effort from you.
#
# Q. How does the “in” keyword work differently for lists and dictionaries ?
# ANS:  The in keyword in Python is used to check membership, but it behaves differently and has different performance characteristics depending on            whether you use it with a list or a dictionary. Checks if a value exists anywhere in the list. It scans the list from start to end until it            finds a match.
#
# Q. Can you modify the elements of a tuple? Explain why or why not ?
# ANS. No, you cannot modify the elements of a tuple in Python because tuples are immutable. You cannot directly modify tuple elements because tuples         are immutable. However, if a tuple holds mutable objects, those inner objects can be changed.
#
# Q. What is a nested dictionary, and give an example of its use case ?
# ANS: A nested dictionary in Python is a dictionary where one or more values are themselves dictionaries. This allows you to create multi-level,             hierarchical data structures. Example Use Case: Storing Information About Employees:
#      employees = { "emp1": "name": "Alice" "age": 30, "department": "HR"  }, "emp2": {"name": "Bob", "age": 25, "department": "Engineering }
#
#
# Q. Describe the time complexity of accessing elements in a dictionary ?
# ANS: Accessing elements in a Python dictionary generally has average-case time complexity of O(1) — constant time.
#      Dictionaries in Python are implemented using hash tables. When you access a value by its key, Python:Computes the hash of the key (a fast              operation). Uses the hash to find the index (bucket) where the key-value pair is stored. Retrieves the value directly from that index. Since this      process doesn’t depend on the size of the dictionary, it’s constant time on average.
#
# Q. In what situations are lists preferred over dictionaries ?
# ANS: Situations and Reasons :
#      Ordered Data :	    Lists maintain the order of elements, which is important if order matters (e.g., processing items sequentially).
#      Simple Collections of Items : 	When you just need to store a sequence of values without key-value pairs.
#      Index-Based Access : Lists allow easy access by position (index), which is faster and more intuitive for numeric indexing.
#
#
# Q. Why are dictionaries considered unordered, and how does that affect data retrieval ?
# ANS: Dictionaries in Python are hash-based collections, designed for fast key-based access, not positional order. Originally (in Python versions < 3.7), dictionaries were considered unordered because:
#             The insertion order of keys was not preserved.
#             The internal order depended on the hash values of keys and could change between executions or when keys were added or removed.
#             This meant you couldn’t reliably predict the order in which items would appear when iterating.
#
#
# Q. Explain the difference between a list and a dictionary in terms of data retrieval.
# ANS: Both lists and dictionaries are used to store collections of data in Python, but how you retrieve data from them is fundamentally different.
#     Feature     	List	             Dictionary
# Access type     	By index	         By key
# Key/index type     	Integer only	     Any hashable object (e.g. string)
# Lookup speed    	Fast (O(1))        	Faster on average (O(1))

# %%
Q.1  Write a code to create a string with your name and print it 
ANS: name = "Vedika"
     print("My name is", name) 

     result will be :
     My name is , Vedika 
         


Q.2  Write a code to find the length of the string "Hello World"
ANS: text = "Hello World"
     length = len(text)
     print("Length of the string is:", length)
     Output:
     Length of the string is: 11



Q.3  Write a code to slice the first 3 characters from the string "Python Programming"
ANS: text = "Python Programming"
     sliced_text = text[:3]
     print("First 3 characters:", sliced_text)
     Output:
     First 3 characters: Pyt



Q.4  Write a code to convert the string "hello" to uppercase
ANS: text = "hello"
     uppercase_text = text.upper()
     print("Uppercase:", uppercase_text)
     Output:
     Uppercase: HELLO



Q.5  Write a code to replace the word "apple" with "orange" in the string "I like apple"
ANS: text = "I like apple"
     new_text = text.replace("apple", "orange")
     print(new_text)
     Output:
     I like orange



Q.6  Write a code to create a list with numbers 1 to 5 and print it
ANS: numbers = [1, 2, 3, 4, 5]
     print("List of numbers:", numbers)
     Output:
     List of numbers: [1, 2, 3, 4, 5]



Q.7  Write a code to append the number 10 to the list [1, 2, 3, 4]
ANS: numbers = [1, 2, 3, 4]
     numbers.append(10)
     print(numbers)
     Output:
     [1, 2, 3, 4, 10]



Q.8  Write a code to remove the number 3 from the list [1, 2, 3, 4, 5]
ANS: numbers = [1, 2, 3, 4, 5]
     numbers.remove(3)
     print(numbers)
     Output:
     [1, 2, 4, 5]



Q.9  Write a code to access the second element in the list ['a', 'b', 'c', 'd']
ANS: letters = ['a', 'b', 'c', 'd']
     second_element = letters[1]
     print("Second element:", second_element)
     Output:
     Second element: b



Q.10  Write a code to reverse the list [10, 20, 30, 40, 50]
ANS:  numbers = [10, 20, 30, 40, 50]
      numbers.reverse()
      print(numbers)
      Output:
      [50, 40, 30, 20, 10]



Q.11  Write a code to create a tuple with the elements 100, 200, 300 and print it.
ANS:  my_tuple = (100, 200, 300)
      print(my_tuple)
      Output:
      (100, 200, 300)




Q.12   Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow').
ANS:   colors = ('red', 'green', 'blue', 'yellow')
       print("Second-to-last element:", second_to_last)
       Output:
       Second-to-last element: blue



Q.13   Write a code to find the minimum number in the tuple (10, 20, 5, 15).
ANS:   numbers = (10, 20, 5, 15)
       min_number = min(numbers)
       print("Minimum number:", min_number)
       Output:
       Minimum number: 5



Q.14   Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').
ANS:   animals = ('dog', 'cat', 'rabbit')
       index_cat = animals.index("cat")
       print('Index of "cat":', index_cat)
       Output:
       Index of "cat": 1



Q.15   Write a code to create a tuple containing three different fruits and check if "kiwi" is in it.
ANS:   fruits = ("apple", "banana", "orange")
       if "kiwi" in fruits:
    print("Kiwi is in the tuple.")
else:
    print("Kiwi is NOT in the tuple.")
    Output:
    Kiwi is NOT in the tuple.



Q.16  Write a code to create a set with the elements 'a', 'b', 'c' and print it.
ANS:  my_set = {'a', 'b', 'c'}
      print(my_set)
      Output :
     {'a', 'b', 'c'}



Q.17  Write a code to clear all elements from the set {1, 2, 3, 4, 5}.
ANS:  my_set = {1, 2, 3, 4, 5}
      my_set.clear()
      print(my_set)
      Output:
      set()



Q.18   Write a code to remove the element 4 from the set {1, 2, 3, 4}.
ANS:   my_set = {1, 2, 3, 4}
       my_set.remove(4)
       print(my_set)
       Output:
       {1, 2, 3}


Q.19  Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}.
ANS:  set1 = {1, 2, 3}
      set2 = {3, 4, 5}
      union_set = set1.union(set2)
     print("Union of sets:", union_set)
     Output:
     Union of sets: {1, 2, 3, 4, 5}



Q.20  Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}.
ANS   set1 = {1, 2, 3}
      set2 = {2, 3, 4}
      intersection_set = set1.intersection(set2)
      print("Intersection of sets:", intersection_set)
      Output:
      Intersection of sets: {2, 3}




Q.21  Write a code to create a dictionary with the keys "name", "age", and "city", and print it.
ANS:  person = { "name": "Alice",  "age": 30, "city": "New York"}
      print(person)
      Output:
      {'name': 'Alice', 'age': 30, 'city': 'New York'}



Q.22  Write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}.
ANS:  person = {'name': 'John', 'age': 25}
      person['country'] = 'USA'
      print(person)
      Output:
      {'name': 'John', 'age': 25, 'country': 'USA'}



Q.23  Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}.
ANS:  person = {'name': 'Alice', 'age': 30}
      name_value = person['name']
      print("Name:", name_value)
      Output:
      Name: Alice
    


Q.24  Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}.
ANS:  person = {'name': 'Bob', 'age': 22, 'city': 'New York'}
      del person['age']
      print(person)
      Output:
      {'name': 'Bob', 'city': 'New York'}



Q.25 Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}.
ANS: person = {'name': 'Alice', 'city': 'Paris'}
     if "city" in person:
    print("Key 'city' exists in the dictionary.")
    else:
    print("Key 'city' does NOT exist in the dictionary.")
    Output:
    Key 'city' exists in the dictionary.



Q.26 Write a code to create a list, a tuple, and a dictionary, and print them all.
ANS: my_list = [10, 20, 30]
     my_tuple = ('apple', 'banana', 'cherry')
     my_dict = {'name': 'Alice', 'age': 25}
     print("List:", my_list)
     print("Tuple:", my_tuple)
     print("Dictionary:", my_dict)
     Output:
     List: [10, 20, 30]
     Tuple: ('apple', 'banana', 'cherry')
     Dictionary: {'name': 'Alice', 'age': 25}



Q.27  Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the
      result.(replaced)
ANS:  import random
      random_numbers = [random.randint(1, 100) for _ in range(5)]
      random_numbers.sort()
      print("Sorted list:", random_numbers)
      Sample Output:
      Sorted list: [12, 35, 47, 68, 90]



Q.28  Write a code to create a list with strings and print the element at the third index.
ANS:  fruits = ["apple", "banana", "cherry", "date", "elderberry"]
      print("Element at index 3:", fruits[3])
      Output:
      Element at index 3: date



Q.29  Write a code to combine two dictionaries into one and print the result.
ANS:  dict1 = {'name': 'Alice', 'age': 25}
      dict2 = {'city': 'New York', 'country': 'USA'}
      combined_dict = dict1 | dict2
      print(combined_dict)
      Output:
      {'name': 'Alice', 'age': 25, 'city': 'New York', 'country': 'USA'}



Q.30  Write a code to convert a list of strings into a set.
ANS:  String_list = ["apple", "banana", "apple", "cherry", "banana"]
      string_set = set(string_list)


print(string_set)
Output (order may vary):
bash
Copy
Edit
{'banana', 'cherry', 'apple'}
